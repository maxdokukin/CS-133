# %%
import pandas as pd

# %%
london_data="https://raw.githubusercontent.com/csbfx/advpy122-data/master/London_daily_rain.csv"
berlin_data="https://raw.githubusercontent.com/csbfx/advpy122-data/master/Berlin_daily_rain.csv"
edinburgh_data="https://raw.githubusercontent.com/csbfx/advpy122-data/master/Edinburgh_daily_rain.csv"

london_rain = pd.read_csv(london_data)
berlin_rain = pd.read_csv(berlin_data)
edinburgh_rain = pd.read_csv(edinburgh_data)

london_rain["City"] = "London"
berlin_rain["City"] = "Berlin"
edinburgh_rain["City"] = "Edinburgh"

all_dfs = [london_rain, berlin_rain, edinburgh_rain]
all_rain = pd.concat(all_dfs)
all_rain
# Out:
#        Year    Month  Day of month  Day of year  Rainfall (mm)       City
# 0      1960  January             1            1           22.0     London
# 1      1960  January             2            2           23.0     London
# 2      1960  January             3            3            7.0     London
# 3      1960  January             4            4            0.0     London
# 4      1960  January             5            5            0.0     London
# ...     ...      ...           ...          ...            ...        ...
# 21757  2019     July            27          208           18.0  Edinburgh
# 21758  2019     July            28          209            0.0  Edinburgh
# 21759  2019     July            29          210            4.0  Edinburgh
# 21760  2019     July            30          211           41.0  Edinburgh
# 21761  2019     July            31          212            0.0  Edinburgh
#
# [65286 rows x 6 columns]

# %%
radar_data = all_rain.groupby(['City', 'Month'])['Rainfall (mm)'].mean()
radar_data = radar_data.reset_index()
radar_data
# Out:
#          City      Month  Rainfall (mm)
# 0      Berlin      April      11.857778
# 1      Berlin     August      20.779661
# 2      Berlin   December      16.405686
# 3      Berlin   February      12.511504
# 4      Berlin    January      14.636559
# 5      Berlin       July      21.183333
# 6      Berlin       June      21.720000
# 7      Berlin      March      12.560753
# 8      Berlin        May      17.438172
# 9      Berlin   November      15.731073
# 10     Berlin    October      13.110443
# 11     Berlin  September      15.110734
# 12  Edinburgh      April      15.064444
# 13  Edinburgh     August      18.052488
# 14  Edinburgh   December      18.763805
# 15  Edinburgh   February      14.615339
# 16  Edinburgh    January      18.551075
# 17  Edinburgh       July      15.823118
# 18  Edinburgh       June      17.145000
# 19  Edinburgh      March      14.610753
# 20  Edinburgh        May      16.579032
# 21  Edinburgh   November      20.920904
# 22  Edinburgh    October      20.441771
# 23  Edinburgh  September      17.741243
# 24     London      April      14.340556
# 25     London     August      17.024057
# 26     London   December      18.149262
# 27     London   February      13.753392
# 28     London    January      17.864516
# 29     London       July      14.919892
# 30     London       June      16.310000
# 31     London      March      13.829570
# 32     London        May      15.792473
# 33     London   November      20.327119
# 34     London    October      19.712958
# 35     London  September      16.934463

# %%
import plotly.graph_objects as go

categories = ["January","February","March","April","May","June","July","August",
"September","October","November","December", 'January']

london_data = radar_data[radar_data.City == 'London']['Rainfall (mm)'].tolist()
london_data.append(london_data[0])

berlin_data = radar_data[radar_data.City == 'Berlin']['Rainfall (mm)'].tolist()
berlin_data.append(berlin_data[0])

edinburgh_data = radar_data[radar_data.City == 'Edinburgh']['Rainfall (mm)'].tolist()
edinburgh_data.append(edinburgh_data[0])

fig = go.Figure()

fig.add_trace(go.Scatterpolar(
      r= london_data,
      theta=categories,
      name='London'
))
fig.add_trace(go.Scatterpolar(
      r = berlin_data,
      theta=categories,
      name='Berlin'
))
fig.add_trace(go.Scatterpolar(
      r=edinburgh_data,
      theta=categories,
      name='Edinburgh'
))

fig.update_layout(
    title='Monthly Average Rainfall (mm)',
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 25]
        ),
        angularaxis=dict(
            rotation=90,
            direction='clockwise'
        )
    ),
    showlegend=True
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f616a2a-9d97-4867-ad67-edbbbaf4b8de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f616a2a-9d97-4867-ad67-edbbbaf4b8de")) {                    Plotly.newPlot(                        "3f616a2a-9d97-4867-ad67-edbbbaf4b8de",                        [{"name":"London","r":[14.340555555555556,17.024056861673046,18.14926189174412,13.75339233038348,17.864516129032257,14.91989247311828,16.31,13.829569892473119,15.79247311827957,20.327118644067795,19.71295790049207,16.93446327683616,14.340555555555556],"theta":["January","February","March","April","May","June","July","August","September","October","November","December","January"],"type":"scatterpolar"},{"name":"Berlin","r":[11.857777777777779,20.779661016949152,16.405686167304538,12.511504424778762,14.636559139784946,21.183333333333334,21.72,12.560752688172043,17.438172043010752,15.731073446327684,13.110442864953527,15.110734463276836,11.857777777777779],"theta":["January","February","March","April","May","June","July","August","September","October","November","December","January"],"type":"scatterpolar"},{"name":"Edinburgh","r":[15.064444444444444,18.052487698195737,18.763805358119193,14.615339233038348,18.551075268817204,15.823118279569892,17.145,14.610752688172044,16.579032258064515,20.92090395480226,20.441771459814106,17.74124293785311,15.064444444444444],"theta":["January","February","March","April","May","June","July","August","September","October","November","December","January"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...
